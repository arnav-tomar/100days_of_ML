# %%
import pandas as pd

url = "https://raw.githubusercontent.com/ageron/data/main/housing/housing.csv"
df = pd.read_csv(url)

print(df.head())
print(df.shape)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# (20640, 10)

# %%
X_df, Y_df = df.data, df['median_house_value']
print('Dataset features names : '+ str(df.feature_names))
print('Dataset features size : '+ str(df.data.shape))
print('Dataset target size : '+ str(df.target.shape))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-908691094.py in <cell line: 0>()
# ----> 1 X_df, Y_df = df.data, df.target
#       2 print('Dataset features names : '+ str(df.feature_names))
#       3 print('Dataset features size : '+ str(df.data.shape))
#       4 print('Dataset target size : '+ str(df.target.shape))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'data'
